# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Samet Egemen Arda**
# Data Scientist

# %% [markdown]
# *I am interested in data science because soon, at least at the basic level, every job under engineering category will require knowledge and/or experience in data science*

# %% [markdown]
# ### The Following Code display the sum of the values of two variables

# %%
a = 5
b = 6
a + b
# Out:
# 11

# %% [markdown]
# Steps to become a Data Scientist:
# 1. Coursera Data Analyst Track
# 2. Coursera Data Scientist Track - Entry Level
# 3. Coursera Data Scientist Track - Senior Level
# ----------
# > Big data is at the foundation of all the megatrends that are happening - Chris Lynch
